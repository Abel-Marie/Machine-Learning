# %% [markdown]
# #Diabete Prediction

# %% [markdown]
# #Problem Statement
#
# * The Objective of this diabets dataset is to predict whether patient has diabetes or not
# * The datasets consiste of several medical predictor (Independent) variables and one target variable, (Outcome).
# * Predictor variables includes `pregnancies, Glucose, Blood Pressure, Skin Thickness, Insulin, BMI, DiabetesPedigreeFunction, age` and `Outcome`

# %% [markdown]
# ###Name of the columns with their meanings
#
# 1. Pregnancies -> Number of times pregnant
# 2. Glucose - Plasma glucose concentration on a 2 houres in an oral glucose tolerance test
# 3. BloodPressure --> Diastolic blood pressure (mm Hg)
# 4. SkinThickness -> Triceps skin fold thickness (mm)
# 5. Insulin -> 2-hour serum insulin (mm U/ml)
# 6. BMI -> Body mass Index (weight in Kg/(height in m)^2)
# 7. DiabetesPedigreeFunction -> Diabetes pedigree function
# 8. Age -> Age (years)
# 9. Outcome -> Class variable (0 or 1)
#               268 of 768 are 1
#               500 of 768 are 0

# %% [markdown]
# ## Step 1: importing libraries like Numpy, Pandas, Matplotlib, Seaborn and scikit learn (Sklearn)
#
# * **Numpy** : is a general-purposse package. It provides a high-performance multidimentional array object. It is the fundamental package for scientific computing with Python Numerical Analysis library
# * **Pandas** : pandas is used for data analytics and for reading of dataset which is in .csv format and Data Preprocessing Pandas is also used for data manipulation. It operations for manipulating numerical data.
# * **Matplotlib** : For Charts or Plots
# * **Seaborn** : For Charts and plots on top of matplotlib, it is a datavisualization library based on matplotlib. It provides a high level interface for drawing attractive and informatics statistical graphics.
# * **Sklearn** : Scikit-learn library provides many unsupervised and supervised learning algorithms. The scikit-learn provides
#    Regression
#    Classification
#    Model selection Preprocessing

# %%
# Numpy
import numpy as np

# Pandas
import pandas as pd

# matplotlib
import matplotlib.pyplot as plt

# Seaborn
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 2: Load the Dataset

# %%
# Load pima indians dataset
df = pd.read_csv('diabetes.csv')

# %% [markdown]
# ##Step 3: Exploratory Data Analysis
#
# Exploratory Data Analysis (EDA), also known as Data Exploration, is a step in the data Analysis Process, where a number of techniques are used to better understanding the dataset being used.
#
# in this step we will perform the below operations:
#
# **3.1 - Understanding your variables**
#
#   3.1.1 - Head of the dataset
#
#   3.1.2 - The shape of the dataset
#
#   3.1.3 - List types of all columns
#
#   3.1.4 - Info of the dataset
#
#   3.1.5 - Summary of the dataset
#
# **3.2 - Data Cleaning ***
#
#  3.2.1 - Check the Dublicates
#
#  3.2.2 - Check the NULL values

# %% [markdown]
# ### **3.1.1 - Head of the dataset**
#
#  The `head()` function will tell you the top records in the dataset. By default, python shows you only the top 5 records.
#
#  This `head(n)` function returns the first n rows for the object based on postion. It is useful for quickly testing if your object has the right type of data in it. By default it will show you 5 rows

# %%
# Display first 5 records of data
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Display the last 5 records of data
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
# Display randomly any number of records of data
df.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 241            4       91             70             32       88  33.1
# 132            3      170             64             37      225  34.5
# 436           12      140             85             33        0  37.4
# 625            4       90             88             47       54  37.7
# 71             5      139             64             35      140  28.6
# 416            1       97             68             21        0  27.2
# 260            3      191             68             15      130  30.9
# 535            4      132              0              0        0  32.9
# 300            0      167              0              0        0  32.3
# 396            3       96             56             34      115  24.7
#
#      DiabetesPedigreeFunction  Age  Outcome
# 241                     0.446   22        0
# 132                     0.356   30        1
# 436                     0.244   41        0
# ...

# %% [markdown]
# ### **3.1.2 -The Shape of the dataset**
#
# Thhis `shape()` function gives us the number of **rows** and **columns** of the dataset.

# %%
# NUmber of rows and columns
df.shape
# Out:
# (768, 9)

# %% [markdown]
# Number of rows = 768
#
# Number of Columns = 9

# %% [markdown]
# ###**3.1.3- List types of columns**
#
# Using `df.dtypes`, we get the list of all the columns in our dataset

# %%
#List the types of columns
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# ###**3.1.4- Info of the dataset**
#
# `info()` is used to check the information about the data and the datatype of each repective attributes

# %%
# Finding out if the dataset contains any null value
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ###**3.1.5- Summary of the dataset**
#
# The discribed method will help to see how data has been spread for numerical values. We can clearly see the minimum value, mean values, different percentile values, and maximum values.

# %%
# Statistical summary
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# **Observation:**
#
# In the above table, the min value of columns `Glucose`, `BloodPressur`, `SkinThickness`, `Insulin`, `BMI` is zero(0). it is clear that this value can't be zero, So we are going to input mean values of this respective columns instead of zero.

# %% [markdown]
# ## **3.2 - Data Cleaning**

# %% [markdown]
# ###**3.2.1- Drop the duplicates**
#
# check if there are any duplicate rows are eist or not, if exist then we should remove from the dataframe

# %%
# check the shape before drop the duplicates
df.shape
# Out:
# (768, 9)

# %%
df = df.drop_duplicates()

# %%
# check the shape after drop the duplicates
df.shape
# Out:
# (768, 9)

# %% [markdown]
# Before drop and after drop the duplicates the data set has same shape which means there is no duplicate value

# %% [markdown]
# ###**3.2.2- Check the NULL value**
#
# Using `isnull.sum()` function we can see the the null values present in the every column in the dataset

# %%
# Count of null values
# check the missing values in any column
# Display number of null values in every column in dataset
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# There is no NULL value in the given dataset

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# **Check the number of Zero values in the dataset**

# %%
print('No. of zero values in Glucose ', df[df['Glucose']==0].shape[0])
# Out:
# No. of zero values in Glucose  5

# %%
print('No. of zero values in BloodPressure ', df[df['BloodPressure']==0].shape[0])
# Out:
# No. of zero values in BloodPressure  35

# %%
print('No. of zero values in SkinThickness ', df[df['SkinThickness']==0].shape[0])
# Out:
# No. of zero values in SkinThickness  227

# %%
print('No. of zero values in Insulin ', df[df['Insulin']==0].shape[0])
# Out:
# No. of zero values in Insulin  374

# %%
print('No. of zero values in BMI ', df[df['BMI']==0].shape[0])
# Out:
# No. of zero values in BMI  11

# %% [markdown]
# **Replace no.of zero values with mean of that columns**

# %%
df['Glucose']=df['Glucose'].replace(0,df['Glucose'].mean())
print('No. of zero values in Glucose ', df[df['Glucose']==0].shape[0])
# Out:
# No. of zero values in Glucose  0

# %%
df['BloodPressure']=df['BloodPressure'].replace(0,df['BloodPressure'].mean())
print('No. of zero values in BloodPressure ', df[df['BloodPressure']==0].shape[0])
# Out:
# No. of zero values in BloodPressure  0

# %%
df['SkinThickness']=df['SkinThickness'].replace(0,df['SkinThickness'].mean())
print('No. of zero values in SkinThickness ', df[df['SkinThickness']==0].shape[0])
# Out:
# No. of zero values in SkinThickness  0

# %%
df['Insulin']=df['Insulin'].replace(0,df['Insulin'].mean())
print('No. of zero values in Insulin ', df[df['Insulin']==0].shape[0])
# Out:
# No. of zero values in Insulin  0

# %%
df['BMI']=df['BMI'].replace(0,df['BMI'].mean())
print('No. of zero values in BMI ', df[df['BMI']==0].shape[0])
# Out:
# No. of zero values in BMI  0

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.681605      72.254807      26.606479  118.660163
# std       3.369578   30.436016      12.115932       9.631241   93.080358
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      20.536458   79.799479
# 50%       3.000000  117.000000      72.000000      23.000000   79.799479
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450805                  0.471876   33.240885    0.348958
# std      6.875374                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ##**4- Data Visualization**

# %% [markdown]
# ###**4.1- Count plot**

# %%
# outcome count plot
f,ax=plt.subplots(1,2,figsize=(10,5))
df['Outcome'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Outcome')
ax[0].set_ylabel('')
sns.countplot('Outcome', data=df, ax=ax[1])
ax[1].set_title('Outcome')
N, P = df['Outcome'].value_counts()
print('Negative (0): ', N)
print('Positive (1): ',P)
plt.grid()
plt.show()
# Out:
# Negative (0):  500
# Positive (1):  268

# %% [markdown]
# Out of total 768 people, 268 are diabetic (Positive(1)) and 500 are non-diabetic (negative (0))
#
# in the outcome column, **1** represents **diabetes postive** and **0** represents **diabetes negative**
#
# The countplot tells us that the dataset is **imbalanced**, as number of patients who don't have diabetes is more than those who have diabetes

# %% [markdown]
# ### **4.2- Histograms**
#
# Histograms are one of the most common graphs used to display numeric data.
#
# Distrubition of the data - Whether the data is normally distributed or it is skewed (to the left to or right)

# %%
# Histograms of each feature
df.hist(bins=10,figsize=(10,10))
plt.show()

# %% [markdown]
# ### **4.3- Scatter plot**
#
# A Scatter plot is a type of graph which 'plots' the values of two variables along with two axis like age and height. Scatter plot are usefull for many reasons like correlation matrices, it allows you to quickely understand a relationship between two variables

# %%
#Scatter plot matrix
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize = (20,20));

# %% [markdown]
# ###**4.4- Pairplot**
#
# `sns.pairplot()` - is a graete way to create scatteplots between all of your variables

# %%
# Pairplot
sns.pairplot(data=df, hue = 'Outcome')
plt.show()

# %% [markdown]
# ### **4.5- Analyzing relationship between variables**
#
# **Correlation analysis**
#
# Correlation analysis is used to quantify the degree to which two variables are related. Through the correlation analysis, you evaluate the correlation coefficent that tells you how much one variable changes when the other one does. Correlation analysis provides you with a linear relationship between two variables, when we correlate feature variables with the target variables, we get to know that how much dependencie is there  between particular feature variables and target variables

# %%
import seaborn as sns
# get correlation of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(10,10))
#Plot the heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True, cmap='RdYlGn')

# %% [markdown]
# **Observations**
#
# From the correlation matrix heatmap, we can see that there is a high correlation between [Pregnancies, Glucose, BMI, Age, Insulin]. we can select these features to accept input from the user and predict the Outcome

# %% [markdown]
# ## **5- Split the data frame into X & y**

# %%
target_name = 'Outcome'

# Separate object for target features
y=df[target_name]

# Separate Object for Input features
X = df.drop(target_name, axis=1)

# %%
X.head()

# %%
y.head()

# %% [markdown]
# ##**6- Apply Feature Scaling**

# %%
# Apply Standard Scales
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
SSX = scaler.transform(X)

# %% [markdown]
# Inplace of Standard Scalar you have to try other data sscaling techniques like normalizer, minmax scaler and binarizer

# %% [markdown]
# ## **7- Train Test Split**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(SSX, y, test_size=0.2, random_state=7)

# %%
X_train.shape, y_train.shape

# %%
X_test.shape, y_test.shape

# %% [markdown]
# ##**8- Build the CLASSIFICATION Algorithm**

# %% [markdown]
# ### **8.1- Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver='liblinear', multi_class='ovr')
lr.fit(X_train, y_train)

# %% [markdown]
# ### **8.2- KNeighborsClassifier (KNN)**

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train, y_train)

# %% [markdown]
# ###**8.3- Naive-Bayes Classifier**

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(X_train, y_train)

# %% [markdown]
# ###**8.4- Support Vector Machine (SVM)**

# %%
from sklearn.svm import SVC
sv=SVC()
sv.fit(X_train, y_train)

# %% [markdown]
# ###**8.5- Decision tree**

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train, y_train)

# %% [markdown]
# ###**8.6- Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(criterion='entropy')
rf.fit(X_train, y_train)

# %% [markdown]
# ##**9- Making Predictions**

# %%
X_test.shape

# %% [markdown]
# ###**9.1- Making prediction on test by using logistic Regression**

# %%
#Making prediction on test dataset
lr_pred=lr.predict(X_test)

# %%
lr_pred.shape
# Out:
# (154,)

# %% [markdown]
# ###**9.2 - Making Prediction on test by using KNN**

# %%
# Making Prediction on test dataset
knn_pred=knn.predict(X_test)

# %%
knn_pred.shape
# Out:
# (154,)

# %% [markdown]
# ###**9.3- Making Predictions on test by using Naive Bayes**

# %%
nb_pred=nb.predict(X_test)

# %%
nb_pred.shape
# Out:
# (154,)

# %% [markdown]
# ###**9.5- Making Prediction on test by using SVM**

# %%
sv_pred=sv.predict(X_test)

# %%
sv_pred.shape
# Out:
# (154,)

# %% [markdown]
# ###**9.5- Making Prediction on test by using Decesion Tree**

# %%
dt_pred=dt.predict(X_test)

# %%
dt_pred.shape
# Out:
# (154,)

# %% [markdown]
# ###**9.6- Making Prediction on test by using Random Forest**

# %%
 rf_pred=rf.predict(X_test)

# %%
rf_pred.shape
# Out:
# (154,)

# %% [markdown]
# ##**10- Model Evaluation**

# %% [markdown]
# ###**10.1- Train Score & Test Score**

# %%
# Train score and test score of logistic regression
from sklearn.metrics import accuracy_score
print('Train accuracy of Logistic Regression ', lr.score(X_train, y_train)*100)
print('Accuracy (Test score of logistic Regression)', lr.score(X_test, y_test)*100)
print('Accuracy (Test score of Logistic Regression)', accuracy_score(y_test, lr_pred)*100)
# Out:
# Train accuracy of Logistic Regression  77.36156351791531
# Accuracy (Test score of logistic Regression) 77.27272727272727
# Accuracy (Test score of Logistic Regression) 77.27272727272727

# %%
# Train score and test score of KNearestNeighbours classifier
from sklearn.metrics import accuracy_score
print('Train accuracy of KNearestNeighbours ', knn.score(X_train, y_train)*100)
print('Accuracy (Test score of KNearestNeighbours)', knn.score(X_test, y_test)*100)
print('Accuracy (Test score of KNearestNeighbours)', accuracy_score(y_test, knn_pred)*100)
# Out:
# Train accuracy of KNearestNeighbours  81.10749185667753
# Accuracy (Test score of KNearestNeighbours) 74.67532467532467
# Accuracy (Test score of KNearestNeighbours) 74.67532467532467

# %%
# Train score and test score of Naive Bayes
from sklearn.metrics import accuracy_score
print('Train accuracy of Naive Bayes ', nb.score(X_train, y_train)*100)
print('Accuracy (Test score of Naive Bayes)', nb.score(X_test, y_test)*100)
print('Accuracy (Test score of Naive Bayes)', accuracy_score(y_test, nb_pred)*100)
# Out:
# Train accuracy of Naive Bayes  74.2671009771987
# Accuracy (Test score of Naive Bayes) 74.02597402597402
# Accuracy (Test score of Naive Bayes) 74.02597402597402

# %%
# Train score and test score of support vector machine
from sklearn.metrics import accuracy_score
print('Train accuracy of support vector machine ', sv.score(X_train, y_train)*100)
print('Accuracy (Test score of support vector machine)', sv.score(X_test, y_test)*100)
print('Accuracy (Test score of support vector machine)', accuracy_score(y_test, sv_pred)*100)
# Out:
# Train accuracy of support vector machine  81.92182410423453
# Accuracy (Test score of support vector machine) 83.11688311688312
# Accuracy (Test score of support vector machine) 83.11688311688312

# %%
# Train score and test score of Decision Trees
from sklearn.metrics import accuracy_score
print('Train accuracy of Decision Trees ', dt.score(X_train, y_train)*100)
print('Accuracy (Test score of Decision Trees)', dt.score(X_test, y_test)*100)
print('Accuracy (Test score of Decision Trees)', accuracy_score(y_test, dt_pred)*100)
# Out:
# Train accuracy of Decision Trees  100.0
# Accuracy (Test score of Decision Trees) 78.57142857142857
# Accuracy (Test score of Decision Trees) 78.57142857142857

# %%
# Train score and test score of Random Forest
from sklearn.metrics import accuracy_score
print('Train accuracy of Random Forest ', rf.score(X_train, y_train)*100)
print('Accuracy (Test score of Random Forest)', rf.score(X_test, y_test)*100)
print('Accuracy (Test score of Random Forest)', accuracy_score(y_test, rf_pred)*100)
# Out:
# Train accuracy of Random Forest  100.0
# Accuracy (Test score of Random Forest) 84.4155844155844
# Accuracy (Test score of Random Forest) 84.4155844155844

# %% [markdown]
# ###**10.2- Confusion Matrix**
#
# Confusion metrics is a table which is used to describe the performance of a classification problem.
# It visualizes the accuracy of a problem by comparing predicted values with the actual values.
# The term used in confusion metrics are True postive(TV), True negative (TN), false positive(FP), and false negative (FN).
#
# **True Positive:** The predicted result is positive, while it is labeled as postive.
#
# **False Positive:** The predicted result is positive, while it is labeled as negative. It calls type I errors as well.
#
# **False Negative:** The predicted result is negative, while it is labeled as positive. it calls Type II errors as well.
#
# **True Negative:** The predicted result is negative, while it is labeled as negative

# %% [markdown]
# ###**10.2.1- Confusion Matrix of "Logistic Regression"**

# %%
from sklearn.metrics import classification_report,confusion_matrix
# Confusion matrix for logistic regression
cm=confusion_matrix(y_test, lr_pred)
cm
# Out:
# array([[86, 11],
#        [24, 33]])

# %%
sns.heatmap(confusion_matrix(y_test, lr_pred), annot=True,fmt="d")

# %% [markdown]
# TN = cm[0,0]
#
# FP = cm[0,1]
#
# FN = cm[1,0]
#
# TP = cm[1,1]

# %%
TN = cm[0,0]
FP = cm[0,1]
FN = cm[1,0]
TP = cm[1,1]

# %%
TN, FP, FN, TP
# Out:
# (86, 11, 24, 33)

# %%
# Making the Confusion Matrix of Logistic Regression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
cm = confusion_matrix(y_test, lr_pred)

print('TN - True Negative {}'.format(cm[0,0]))
print('FP - False Positive {}'.format(cm[0,1]))
print('FP - False Negative {}'.format(cm[1,0]))
print('TP - True Positive {}'.format(cm[1,1]))
print('Accuracy Rate: {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]),np.sum(cm))*100))
print('Misclassification Rate: {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))*100))
# Out:
# TN - True Negative 86
# FP - False Positive 11
# FP - False Negative 24
# TP - True Positive 33
# Accuracy Rate: 77.27272727272727
# Misclassification Rate: 22.727272727272727

# %%
77.27272727272727 + 22.727272727272727
# Out:
# 100.0

# %%
import matplotlib.pyplot as plt
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Wistia)
classNames = ['0', '1']
plt.title('Confusion Matrix of Logistic Regression')
plt.ylabel('Actual(true) values')
plt.xlabel('Predicted values')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN', 'FP'], ['FN', 'TP']]
for i in range(2):
  for j in range(2):
    plt.text(j,i, str(s[i][j])+" =  " +str(cm[i][j]))
    plt.show()

# %%
# Out:
# col_0     0   1
# Outcome
# 0        86  11
# 1        24  33
